# %% [markdown]
# # Week 1 Extended Setup: How to use Google Colabs and Github for Ling 144
#
# This tutorial will link your **GitHub account** with a folder you specify in your **Google Drive**.
#
#
#
#
#
#
# ## Step 0: Github Access
#
# Make sure that you have already followed the steps [here](!!!INSERT LINK!!!) to set up a Github account and clone the [Course Repository](https://github.com/berlinguist/Ling144-Winter2022).
#
# ## Step 1: Mount Google Drive
#
# 1. Run the following code to mount your own Google Drive:

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# 2. Click on the link that appears to get your authentication code. Make sure you are using your UCSC Google Drive!
# 3. Copy & paste the authentication code into the text box provided

# %% [markdown]
# ## Step 2: Change your working directory
#
# Google Colabs allow you to execute python commands as well as shell commands. We will generally be using Colabs to execute Python code, which is how you mounted the Google Drive above. But to interface with other files in your project, we will also be using shell commands, which are distinguished in the code boxes as being prefixed with a `%`.
#
# When you first mount your drive, you'll need to change directories ("cd") into your `MyDrive` folder. Executing the commands below do the following things:
#
# 1. Changes directories so that you are at the topmost level of your Google Drive folder
# 2. Uses the "make directory" (`mkdir`) command to create a new folder called `Github`
# 3. Changes directories so that you are inside the `Github` folder

# %%
% cd /content/drive/MyDrive
% mkdir Github
% cd Github

# %% [markdown]
# ## Step 3: Generate a Github Access Token
#
# You now need to link your Google Drive account to your Github account so that you can use Google Colabs as an intermediary to sync files from one location to another.
#
# 1. Log in to your Github account.
# 2. Click on your avatar in the upper right of the screen and navigate to **Settings > Developer Settings > Personal Access Tokens**
# 3. Click on the **Generate New Token** button in the top right
# 4. In the form that appears, fill in the following:
#    * **Note**: Github Access token for Colabs
#    * **Expiration**: 90 days
#    * **Select Scopes**:
#       * *check the* **repo** *checkbox*
#       * *check the* **admin:repo_hook** *checkbox*
#       * *check the* **admin:public_key** *checkbox*
# 5. Scroll to the bottom of the page and click the **Generate token** button
# 6. Copy the token that appears in the green box and paste somewhere accessible.

# %% [markdown]
# ## Step 4: Clone your copy of the class repository to your Google Drive
#
# It's now time to sync your Google Drive with your copy of the class repository. You'll be making a link between your private files that you can edit/create/manipulate on your Google Drive and your copy of the public class repository.
#
# 1. Using your Github username and the access token you have just generated, modify the following code chunk with your variables, replacing **\<access-token>** and **\<your-username>** with your credentials. For reference, mine looks something like this:
#
#   `!git clone https://ghp_V7VtrBqPoVtRCtGO158rVUARbGry0MH3g3@github.com/berlinguist/Ling144-Winter2022`
#
# 2. Run the code. You should see a message like this, which indicates that you have successfully cloned your Github repository into your Google Drive:
#   ![Screen Shot 2021-12-19 at 15.29.32.png](data:image/png;base64,...)

# %%
# !git clone https://<access-token>@github.com/<your-username>/Ling144-Winter2022

# %% [markdown]
# Change into your new Ling144-Winter2022 directory.

# %%
% cd Ling144-Winter2022
% ls -la

# %% [markdown]
# ## Step 5: Finish up Github Authentication
#
# This last step finalizes your authentication for Github by setting your email and user name as administrators for the account. This allows you to perform Github command line operations from inside a Colab. You will then be able to make changes to the files stored in your Google Drive, and once you are satisfied with your changes, push them to your Github repository.
#
# It's crucial that you use the same credentials that you used when you set up yout Github account. Replace the variables below with your information, and then run the code chunk. Here's what mine looks like:
#
# ```
# !git config --global user.email "knkraus@ucsc.edu"
# !git config --global user.name "Kelsey Kraus"
# ```

# %%
# !git config --global user.email "your-email@example.com"
# !git config --global user.name "Your Name"

# %% [markdown]
# ## You're set up!
#
# You should now have established a link between your Github repository and your Google Drive class folder.

# %% [markdown]
# ---
#
# # **Recap**
#
# By setting up this link between your accounts, you have:
#  - Downloaded our class repository into your Google Drive
#  - Minimally changed this file by adding your authentication details
#  - Set up a connection between your local copy of the class repository (stored in your Google Drive) and your Github repository to track changes that you make during the course of this class

# %%
% cd /content/drive/MyDrive/Github/
% cd Ling144-Winter2022/
% ls
# Out:
# /content/drive/MyDrive/Github
# /content/drive/MyDrive/Github/Ling144-Winter2022
# README.md  Week-1/

# %% [markdown]
# **You do not need to perform the actions below!**

# %%
# !git status
